# %% [markdown]
# <a href="https://colab.research.google.com/github/atmakurinikitha2005-unqe/Logic-Building-Task-/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks = [45, 78, 90, 33, 60]
pcount=0
fcount=0
for i in marks:
    if i>=50:
         pcount+=1
    else:
         fcount+=1
print("total number of students passed", pcount)
print("total number of students failed", fcount)
# Out:
# total number of students passed 3
# total number of students failed 2
