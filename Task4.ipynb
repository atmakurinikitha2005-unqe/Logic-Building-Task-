# %% [markdown]
# <a href="https://colab.research.google.com/github/atmakurinikitha2005-unqe/Logic-Building-Task-/blob/main/Task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
messages = ["Hi", "Welcome to the platform", "OK"]
for i in messages:
       l=len(i)
       if l>10:
          print(i,":This is flagged message longer than 10 characters.Length=",l)
       else:
          print(i,":Length=",l)
# Out:
# Hi :Length= 2
# Welcome to the platform :This is flagged message longer than 10 characters.Length= 23
# OK :Length= 2
