# %% [markdown]
# <a href="https://colab.research.google.com/github/atmakurinikitha2005-unqe/Logic-Building-Task-/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names = [" Alice ", "bob", " CHARLIE "]
cleanedlist=[]
for i in names:
     cleanedlist.append(i.strip().lower())
print(cleanedlist)
# Out:
# ['alice', 'bob', 'charlie']
